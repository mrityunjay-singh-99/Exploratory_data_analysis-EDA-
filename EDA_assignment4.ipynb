# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the bank data
path=r"C:\Users\Mrityunjay\Desktop\Data science naresh it\Class notes by me\bank.csv"
bank_df=pd.read_csv(path,sep=";")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
colm=bank_df.columns
colm
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
#pick the categorical colomns
cat_colm=[]
for key,value in dict(bank_df.dtypes).items():
    if value=="object":
        cat_colm.append(key)
print(cat_colm)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments'

# %%
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\value_count_df')

# %%
data_frame=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\value_count_df'

# %%
#change into dataframe and plot them
for i in cat_colm:
    dfn=bank_df[i].value_counts()
    keys=dfn.keys()
    value=dfn.values
    col=[i,"count"]
    df=pd.DataFrame(zip(keys,value),columns=col)
    df.to_csv(f'{data_frame}\\{i}.csv',index=False)

    plt.bar(i,"count",data=df)
    plt.xlabel(f"{i}")
    plt.ylabel("class frequency")
    plt.savefig(f"{data_frame}\\{i}_bank_df.jpg")
    plt.show()

# %%
root_diractory=os.getcwd()
new_folder="matplot_graphs"
matplot_dir=os.path.join(root_diractory,new_folder)
os.makedirs(matplot_dir)

# %%
for i in cat_colm:
    dfn=bank_df[i].value_counts()
    keys=dfn.keys()
    value=dfn.values
    col=[i,"count"]
    df=pd.DataFrame(zip(keys,value),columns=col)
    df.to_csv(f'{matplot_dir}\\{i}.csv',index=False)

# %%
matplot_df=os.listdir(matplot_dir)
matplot_df
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'job.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
#pd.read_csv('contact.csv')

# %%
for i in matplot_df:
    dfs=pd.read_csv(f"{matplot_dir}\\{i}")
    plt.title("Bar_Graph")
    plt.bar(i[:-4],"count",data=dfs)
    plt.xlabel(f"{i}")
    plt.ylabel("class frequency")
    plt.savefig(f"{matplot_dir}\\{i}_matplot.jpg")
    plt.show()

# %%
#create seaborn directory

root_sea=os.getcwd()
new_folder="seaborn_graphs"
seaborn_dir=os.path.join(root_sea,new_folder)
os.makedirs(seaborn_dir)

# %%
#categorical columns
cat_colm
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
for i in cat_colm:
    sns.countplot(data=bank_df,
                 x=i)
    plt.title("Bar_graph")
    plt.xlabel(f"{i}")
    plt.ylabel("class frequency")
    plt.figure(figsize=(8,5))
    plt.savefig(f"{seaborn_dir}\\{i}.seaborn.jpg")
    plt.show()

# %%
#all cloumns of bankdatasets
colm
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
#again try
root_dir=os.getcwd()
new_folder="data_frames"
new_dir=os.path.join(root_dir,new_folder)
os.makedirs(new_dir)

# %%
for i in colm:
    cnf=bank_df[i].value_counts()
    keys=cnf.keys()
    value=cnf.values
    df=pd.DataFrame(zip(keys,value),columns=[i,"count"])
    df.to_csv(f"{new_dir}\\{i}.csv")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments'

# %%
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\matplot_graph')

# %%
mat_lib=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\matplot_graph'

# %%
for i in colm:
    dfs=pd.read_csv(f"{new_dir}\\{i}.csv")
    plt.bar(i,"count",data=dfs)
    plt.title("Bar_graphs")
    plt.xlabel(f"{i}")
    plt.ylabel("count")
    plt.savefig(f"{mat_lib}\\{i}.jpg")   
    plt.show()

# %%
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\matplot_seaborn_graphs')

# %%
sea_born=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class Assiments\\matplot_seaborn_graphs'

# %%
orders={}
for i in colm:
    cnf=bank_df[i].value_counts()
    
    orders[i]=cnf.keys()
    
    
for j in colm:
    
    sns.countplot(data=bank_df,
                 x=j,
                 order=orders[j])
    plt.title("Bar_graphs")
    plt.xlabel(f"{i}")
    plt.ylabel("class frequency")
    plt.show()
